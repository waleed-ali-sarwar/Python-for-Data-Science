# %%
pip install tensorflow

# %% [markdown]
# # Boxplot | Intro

# %% [markdown]
# # Boxplot | using tips data set
# ## Categorical

# %%
# learning a Boxplot
import seaborn as my_seaborn
import matplotlib.pyplot as my_mat
import numpy as my_numpy

# theme
my_seaborn.set_theme(style='whitegrid', color_codes=True)
# data set
mydata = my_seaborn.load_dataset('tips')
# figure size
my_mat.figure(figsize=(15,8))
# plot graph
my_seaborn.boxplot(x ='day', y ='tip',data= mydata,saturation=1)

# graph title
my_mat.title('Boxplot| tips dataset | data visualization'.upper())

# show graph
my_mat.show()

# %% [markdown]
# ## Describe() the data set
#
# ### Nummerical

# %%
import seaborn as my_seaborn

# data set 
tips = my_seaborn.load_dataset('tips')
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# ## Boxplot | Tip data set

# %%
import seaborn as _s
import matplotlib.pyplot as _m
# data set
s_data = _s.load_dataset('tips')
# figure size
_m.figure(figsize=(15,8))
# style
_s.set_style('whitegrid')
# plot graph
_s.boxplot(x=s_data['size'])
# title
_m.title('boxplot | tips dataset | data visualization'.upper())
# Out:
# Text(0.5, 1.0, 'BOXPLOT | TIPS DATASET | DATA VISUALIZATION')

# %% [markdown]
# ## Boxplot | Dodge property

# %%
import seaborn as ss
import matplotlib.pyplot as mm

# theme 
ss.set_theme(style='dark',color_codes=True)
# figure size
mm.figure(figsize=(18,8))
# data set
mydata = ss.load_dataset('tips')
mydata
# title
mm.title('boxplot | dodge property | tips dataset | data visualization'.upper())
# plot graph
gg = ss.boxplot(x ='tip',y='day',data= mydata,hue='smoker',dodge=True)

# %% [markdown]
# ## Boxplot | dodge property - FALSE

# %%
import seaborn as ss
import matplotlib.pyplot as mm

# theme 
ss.set_theme(style='ticks',color_codes=True)
# figure size
mm.figure(figsize=(18,8))
# data set
mydata = ss.load_dataset('tips')
mydata
# title
mm.title('boxplot | dodge property | tips dataset | data visualization'.upper())

# plot graph
gg = ss.boxplot(x ='tip',orient='h',y='day',data= mydata,dodge=False,hue='smoker', saturation=1)

# %% [markdown]
# # Manually Boxplot | Data Visualization
# ## Using Titanic Data Set

# %%
# import libraries
import seaborn as _ss
import matplotlib.pyplot as _mpp
# data set 
mydata = _ss.load_dataset('titanic')
# figure size
_mpp.figure(figsize=(18,8))
_ss.boxplot(
    x = 'survived',
    y = 'age',
    hue = 'who',
    showmeans = True,
    data = mydata
)
_mpp.xlabel('Age (Years)',size =16 , weight = 'bold')
_mpp.ylabel('How many survived in Titanic')
# show graph
_mpp.show()

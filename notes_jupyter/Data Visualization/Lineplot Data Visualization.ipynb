# %% [markdown]
# # Most Import Important Libraries
# ### Seaborn automatically installs the following libraries in below.
# - NumPY
# - SciPY
# - Pandas
# - Matplotlib

# %% [markdown]
# # Phool Data Set

# %%
# import libraries
import seaborn as _seaborn
import matplotlib.pyplot as _matplot

# selecting a dataset
my_data = _seaborn.load_dataset('iris')
print(my_data)
_matplot.title('Flowers | Line Plot | Data Visualization'.upper())

data_plot = _seaborn.lineplot(x ='sepal_length', y ='sepal_width', data =my_data)

data_plot.set_title('')

_matplot.show()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Adding limit

# %%
import seaborn as s
import matplotlib.pyplot as m
import pandas as p
# theme
s.set_theme(style='ticks',color_codes=True)
# data
# d = p.read_csv('C:/Users/walee/Desktop/Python Course/Python-for-Data-Science/data/student_set.csv')
d = s.load_dataset('iris')
# title
m.title('Flowers data set with limit | Data Visualization')
# plot graph
l = s.lineplot(x= 'sepal_length',data =d,y='sepal_width')
# limitations
m.xlim(1) # x - axis limit
m.ylim(0) # y - axis limit
# print data excel
print(d)
# show graph | plot
m.show()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # seaborn set styles
# - darkgrid
# - whitegrid
# - dark
# - white
# - ticks

# %%
# import libraries
import seaborn as _seaborn
import matplotlib.pyplot as _matplot

_seaborn.set_theme(style ='dark',color_codes=True)
# selecting a dataset
my_data = _seaborn.load_dataset('iris')
data_plot = _seaborn.lineplot(x ='sepal_length', y ='sepal_width', data =my_data)
_matplot.title('Flowers Dataset  with set_styles | Data Visualization')
# Reason of error is set_style dose not declear with seaborn variable
_seaborn.set_style(style=None,rc=None)
# dark theme
# Assignment
"""
Solution:
    set_style() function must be called with the object _seaborn. So, we should call it from seaborn
"""
# _seaborn.set_style('darkgrid')
_matplot.show()

# %%
# learning a plots
import pandas as my_panda
import seaborn as my_seaborn
import matplotlib.pyplot as my_mat

# theme
my_seaborn.set_theme(style='ticks',color_codes= True)
# data set
mydata = my_panda.read_csv('C:/Users/walee/Desktop/Python Course/Python-for-Data-Science/data/student_set.csv') 
# plot graph
graph = my_seaborn.barplot(x='COUNTRY',data= mydata,y ='AGE')
# graph title 
graph.set_title('Total Student our country | Data Visualization')
# show graph
my_mat.show()

# %%
import seaborn as s
import matplotlib.pyplot as m

# theme
s.set_theme(style='ticks',color_codes=True)
s.set_style("dark")
# data 
mydata = s.load_dataset('iris')
print(mydata)
m.title('Iris | Data Visualization')
graphs = s.lineplot(x='sepal_length',y='sepal_width',data= mydata)
m.figure(figsize=(10,10))
m.show()

# %% [markdown]
# ## Assignment 1

# %%
# import libraries
import seaborn as _seaborn
import matplotlib.pyplot as _matplot

# selecting a dataset
my_data = _seaborn.load_dataset('iris')

# figure size
_matplot.figure(figsize=(18,8))

# data set
data_plot = _seaborn.lineplot(x ='sepal_length', y ='sepal_width', data =my_data)

# title
_matplot.title('Flowers Dataset  with set_styles | Data Visualization')

# Reason of error is set_style dose not declear with seaborn variable
_seaborn.set_style(style=None,rc=None)
# Assignment
"""
Solution:
    set_style() function must be called with the object _seaborn. So, we should call it from seaborn
"""
_seaborn.set_style('whitegrid',{"grid.color": "0"})
_matplot.show()
